# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup

import pandas as pd

import hvplot.pandas

import requests

import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV output from Part 1
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0            hilo  19.7297 -155.0900     25.85        82         100
# 1        1           yanbu  24.0891   38.0637     28.02        61           0
# 2        2  port elizabeth -33.9180   25.5701     14.06        81           0
# 3        3   port mathurin -19.6833   63.4167     25.01        71           4
# 4        4     west island -12.1568   96.8225     28.99        79          75
#
#    Wind Speed Country        Date
# 0        3.60      US  1699500331
# 1        5.14      SA  1699500331
# 2        2.57      ZA  1699500332
# 3        8.06      MU  1699500333
# 4        5.66      CC  1699500109

# %%
# Capitalization of city names
city_data_df.City = city_data_df.City.str.title()
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0            Hilo  19.7297 -155.0900     25.85        82         100
# 1        1           Yanbu  24.0891   38.0637     28.02        61           0
# 2        2  Port Elizabeth -33.9180   25.5701     14.06        81           0
# 3        3   Port Mathurin -19.6833   63.4167     25.01        71           4
# 4        4     West Island -12.1568   96.8225     28.99        79          75
#
#    Wind Speed Country        Date
# 0        3.60      US  1699500331
# 1        5.14      SA  1699500331
# 2        2.57      ZA  1699500332
# 3        8.06      MU  1699500333
# 4        5.66      CC  1699500109

# %%
# Rename Lat and Lng for better presentation in Map
city_data_df = city_data_df.rename(columns={'Lat' : 'Latitude', 'Lng' : 'Longitude'})
city_data_df.columns
# Out:
# Index(['City_ID', 'City', 'Latitude', 'Longitude', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
city_humidity_map = city_data_df.hvplot.points(
    "Longitude",
    "Latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 1200,
    frame_height = 800,
    size = "Humidity",
    color = "City"
)

# Display the map
city_humidity_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %%
# %%capture --no-display

# Rename the columns in the city_data_df dataframe to 'lng' and 'lat'
city_data_df = city_data_df.rename(columns={'Lng': 'lng', 'Lat': 'lat'})

# %%
# Create the map plot
map_plot = city_data_df.hvplot.points('Longitude', 'Latitude', geo=True, tiles='OSM', hover_cols=['City'], size='Humidity', c='City', width=1200, height=600)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather = city_data_df.loc[(city_data_df["Cloudiness"] == 0) & (city_data_df["Max Temp"] < 28) & 
                            (city_data_df["Max Temp"] > 20)]

# Drop any rows with null values
ideal_weather = ideal_weather.dropna(how='any')

#Display ideal weather dataframe
ideal_weather_df
# Out:
#      City_ID               City  Latitude  Longitude  Max Temp  Humidity  \
# 20        20          Al Jubayl   27.0112    49.6583     24.43        55
# 23        23    Remire-Montjoly    4.9167   -52.2667     25.02        94
# 109      109                Sur   22.5667    59.5289     26.09        67
# 114      114        Nova Vicosa  -17.8919   -39.3719     22.32        73
# 131      131           Coruripe  -10.1256   -36.1756     24.21        83
# 139      139            Catalao  -18.1658   -47.9464     22.24        52
# 143      143           Faliraki   36.3398    28.1994     21.16        81
# 186      186      Mount Gambier  -37.8333   140.7667     21.47        45
# 277      277               Qina   26.1642    32.7267     24.47        34
# 280      280       Saint-Pierre  -21.3393    55.4781     25.66        69
# 295      295     Saint-Philippe  -21.3585    55.7679     25.62        78
# 309      309              Arish   31.1316    33.7984     21.72        80
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather.copy()
hotel_df = hotel_df.rename(columns={'Latitude': 'Lat', 'Longitude': 'Lng'})
hotel_df = hotel_df[["City", "Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ''

# Display sample data
hotel_df.head()
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 20         Al Jubayl      SA  27.0112   49.6583        55
# 23   Remire-Montjoly      GF   4.9167  -52.2667        94
# 58         Carnarvon      AU -24.8667  113.6333        60
# 71   Arraial Do Cabo      BR -22.9661  -42.0278        78
# 77  West Hattiesburg      US  31.3191  -89.3751        85

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    'apiKey': geoapify_key,
    'format': 'json',
    'categories': 'accommodation.hotel'
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Al Jubayl - nearest hotel: Sharq
# Remire-Montjoly - nearest hotel: Complexe Belova
# Carnarvon - nearest hotel: No hotel found
# Arraial Do Cabo - nearest hotel: No hotel found
# West Hattiesburg - nearest hotel: Microtel Inn & Suites
# Sur - nearest hotel: Sur Hotel
# Nova Vicosa - nearest hotel: Pousada Pontal da Barra
# Faliraki - nearest hotel: Platon
# Marana - nearest hotel: White Stallion Ranch
# Qina - nearest hotel: Basma Hotel
# Saint-Pierre - nearest hotel: Tropic Hotel
# Bandar Abbas - nearest hotel: هتل دریا
# Arish - nearest hotel: سينا
# Hobbs - nearest hotel: Days Inn by Wyndham Hobbs
# Alice - nearest hotel: No hotel found
# Khark - nearest hotel: No hotel found
# Arinos - nearest hotel: No hotel found
# Winter Park - nearest hotel: Alfond Inn Rollins
# Ciudad Del Carmen - nearest hotel: Holiday Inn Express
# Medina - nearest hotel: The Oberoi Madina
# Tshabong - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
hotel_df = hotel_df.rename(columns={'Lng': 'Longitude', 'Lat': 'Latitude'})

hotel_df_map = hotel_df.hvplot.points('Longitude', 'Latitude', geo=True, tiles='OSM', 
                                      hover_cols=['City', 'Hotel Name', 'Country'], 
                                      size='Humidity', c='City', width=1200, height=600)

# Display the map
hotel_df_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)
